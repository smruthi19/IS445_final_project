# %%
"""Dataset Info"""

"""
Name of dataset: Fossil Fuels CO2 Emissions by Nation

Dataset link: https://datahub.io/core/co2-fossil-by-nation

Dataset download: https://r2.datahub.io/clt98o9xp0001jm08i5u4iewg/master/raw/data/fossil-fuel-co2-emissions-by-nation.csv

License: This Data Package is licensed by its maintainers under the Public Domain Dedication and License (PDDL).

Size: 759 kB

"""
# Out:
# '\nName of dataset: Fossil Fuels CO2 Emissions by Nation\n\nDataset link: https://datahub.io/core/co2-fossil-by-nation\n\nDataset download: https://r2.datahub.io/clt98o9xp0001jm08i5u4iewg/master/raw/data/fossil-fuel-co2-emissions-by-nation.csv\n\nLicense: This Data Package is licensed by its maintainers under the Public Domain Dedication and License (PDDL).\n\nSize: 759 kB\n\n'

# %%
"""
Characteristics of this dataset:

This fossil fuel data contains co2 emissions by country and year. It contains the total fuel, solid fuel, liquid fuel, gas fuel, cement, gas flaring, and bunker fuels for each country.
Overall, there are 17233 rows in the dataset.
Some of the data is string, and some of them are numbers.
"""
# Out:
# '\nCharacteristics of this dataset:\n\nThis fossil fuel data contains co2 emissions by country and year. It contains the total fuel, solid fuel, liquid fuel, gas fuel, cement, gas flaring, and bunker fuels for each country.\nOverall, there are 17233 rows in the dataset.\nSome of the data is string, and some of them are numbers.\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv',encoding='iso-8859-1')
df[:100]
# Out:
#     Year                       Country   Total  Solid Fuel  Liquid Fuel  \
# 0   2014                   AFGHANISTAN    2675        1194         1393
# 1   2014                       ALBANIA    1559         191         1053
# 2   2014                       ALGERIA   39651         149        14422
# 3   2014                       ANDORRA     126           0          126
# 4   2014                        ANGOLA    9480           0         5310
# ..   ...                           ...     ...         ...          ...
# 95  2014      ISLAMIC REPUBLIC OF IRAN  177115         900        66662
# 96  2014                        ISRAEL   17617        6775         6013
# 97  2014  ITALY (INCLUDING SAN MARINO)   87377       13532        39265
# 98  2014                       JAMAICA    2024          75         1835
# 99  2014                         JAPAN  331074      122461       133395
#
#     Gas Fuel  Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# ...

# %%
# Chart 1: Bar chart of highest per capita for top 10 countries over all of the years

per_capita_by_country = df.groupby('Country')["Per Capita"].sum()
sorted_values = per_capita_by_country.sort_values(ascending=False)
top_10=sorted_values.head(10)
top_10.plot(title= "Highest per capita (10 countries)", kind="bar", color = 'blue')
plt.xlabel('Country')
plt.ylabel('Per Capita')
plt.show()

# %%
# Chart 2: Bar chart of highest liquid fuel for top 10 countries over all of the years

liquid_fuel_by_country = df.groupby('Country')["Liquid Fuel"].sum()
sorted_values = liquid_fuel_by_country.sort_values(ascending=False)
top_10=sorted_values.head(10)
top_10.plot(title= "Highest Liquid Fuel (10 countries)", kind="bar", color = 'orange')
plt.ylim(0, top_10.max()*1.2)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.xlabel('Country')
plt.ylabel('Liquid Fuel')
plt.show()

# %%
# Chart 3: Bar chart of highest solid fuel for top 10 countries over all of the years

solid_fuel_by_country = df.groupby('Country')["Solid Fuel"].sum()
sorted_values = solid_fuel_by_country.sort_values(ascending=False)
top_10=sorted_values.head(10)
top_10.plot(title= "Highest Solid Fuel (10 countries)", kind="bar", color = 'pink')
plt.ylim(0, top_10.max()*1.2)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.xlabel('Country')
plt.ylabel('Solid Fuel')
plt.show()
